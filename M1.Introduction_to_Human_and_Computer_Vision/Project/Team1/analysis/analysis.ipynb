# %%
import pandas as pd

# %%
df_week2 = pd.read_csv("results/eval_colorspace_distance_n_bins_n_levels_qsd2_w1_DDBB_w2.csv")
df_week1 = pd.read_csv("results/eval_colorspace_distance.csv")

# %%
df_week1.head()
# Out:
#   Color space            Distance   K  MapK  correct  total
# 0   grayscale  euclidean_distance   1   0.0        0     30
# 1   grayscale  euclidean_distance   5   0.0        0     30
# 2   grayscale  euclidean_distance  10   0.0        0     30
# 3   grayscale         l1_distance   1   0.0        0     30
# 4   grayscale         l1_distance   5   0.0        0     30

# %%
# Distance==eucledian_distance, k=1, np.max(Mapk) 
df_week1[(df_week1["K"]==5)].sort_values(by="MapK", ascending=False)
# Out:
#     Color space                Distance  K       MapK  correct  total
# 55       CieLab        hellinger_kernel  5  62.333333       18     30
# 97          HSV        hellinger_kernel  5  62.333333       18     30
# 76        YCbCr        hellinger_kernel  5  57.444444       17     30
# 79        YCbCr       cosine_similarity  5  54.555556       16     30
# 34          RGB        hellinger_kernel  5  50.833333       15     30
# 100         HSV       cosine_similarity  5  49.944444       14     30
# 58       CieLab       cosine_similarity  5  49.444444       14     30
# 13    grayscale        hellinger_kernel  5  41.500000       12     30
# 37          RGB       cosine_similarity  5  38.611111       11     30
# 16    grayscale       cosine_similarity  5  35.111111       10     30
# 73        YCbCr  histogram_intersection  5  32.777778        9     30
# 40          RGB   histogram_correlation  5  18.666667        5     30
# ...

# %%
df_week2.head()
# Out:
#   Color space  Distance  Num Bins          Num Levels   K       MapK  correct  \
# 0   grayscale         4         2  euclidean_distance   1  46.666667       14
# 1   grayscale         4         2  euclidean_distance   5  55.388889       16
# 2   grayscale         4         2  euclidean_distance  10  55.388889       16
# 3   grayscale         4         2         l1_distance   1  50.000000       15
# 4   grayscale         4         2         l1_distance   5  57.500000       17
#
#    total
# 0     30
# 1     30
# 2     30
# 3     30
# 4     30
